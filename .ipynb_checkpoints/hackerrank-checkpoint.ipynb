# %%
import pandas as pd

# %%
data=pd.read_csv('F:/Python Programs/DataSets/hackerrank/training_dataset.csv')

# %% [markdown]
# #Data Cleaning getting rid of nan

# %%
data.head(10)
# Out:
#                                         user_id  \
# 0  AR+tMy3H/E+Re8Id20zUIz+amJkv6KU12o+BrgIDin0=
# 1  1P4AOvdzJzhDSHi7jJ3udWv4ajpKxOn4T/rCLv4PrXU=
# 2  OEfFUcsTAGInCfsHuLZuIgdSNtuNsg8EdfN98VUZVTs=
# 3  1P4AOvdzJzhDSHi7jJ3udWv4ajpKxOn4T/rCLv4PrXU=
# 4  CYRcuV0cR0algMZJ1N6+3uKcqi8iu+6tJNzmBbmgN7o=
# 5  UREtRIcAzBFKmMt9ZSkFLofOWKAKmzsDD7BwrdxcPuk=
# 6  NiDHS4AU/QOs3ppF618O6bUg8BxJd+EV4Ek26KWrDc0=
# 7  sGNmP4gGVwh3YBpXtq6ZI05PIa3Z0iUaF+ujKonctu0=
# 8  nyoFu8qU0B5viJDXfrVRQ65ytOSSSY3c7okcjo1Z76M=
# 9  A2EUbD7QN5SXpJ7FhPY5Ne7zwjwYhRvAheGskLl0Os8=
#
#                                         mail_id     mail_category  \
# 0  DQ/4I+GIOz2ZoIiK0Lg0AkwnI35XotghgUK/MYc101I=   mail_category_2
# 1  BL3z4RtiyfIDydaRYWX2ZXL6IX10QH1yG5ak1s/8Lls=   mail_category_1
# 2  BL3z4RtiyfIDydaRYWX2ZXL6IX10QH1yG5ak1s/8Lls=   mail_category_1
# 3  EHNBRbi6i9KO6cMHsuDPFjZVp2cY3RH+BiOKwPwzLQs=   mail_category_1
# 4  K0y/NW59TJkYc5y0HUwDeAXrewYT0JQlkcozz0s2V5Q=   mail_category_4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486048 entries, 0 to 486047
# Data columns (total 54 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   user_id                               486048 non-null  object
#  1   mail_id                               486048 non-null  object
#  2   mail_category                         485623 non-null  object
#  3   mail_type                             485623 non-null  object
#  4   sent_time                             486048 non-null  int64
#  5   open_time                             161347 non-null  float64
#  6   click_time                            27084 non-null   float64
#  7   unsubscribe_time                      1958 non-null    float64
#  8   last_online                           485471 non-null  float64
#  9   hacker_created_at                     486048 non-null  int64
# ...

# %%
data2=data.iloc[:,:][data['mail_category'].isna()==False].copy()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485623 entries, 0 to 486047
# Data columns (total 54 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   user_id                               485623 non-null  object
#  1   mail_id                               485623 non-null  object
#  2   mail_category                         485623 non-null  object
#  3   mail_type                             485623 non-null  object
#  4   sent_time                             485623 non-null  int64
#  5   open_time                             161115 non-null  float64
#  6   click_time                            26993 non-null   float64
#  7   unsubscribe_time                      1958 non-null    float64
#  8   last_online                           485046 non-null  float64
#  9   hacker_created_at                     485623 non-null  int64
# ...

# %%
l=[]
for i in data2.columns:
    l.append(i)
print(l)
# Out:
# ['user_id', 'mail_id', 'mail_category', 'mail_type', 'sent_time', 'open_time', 'click_time', 'unsubscribe_time', 'last_online', 'hacker_created_at', 'hacker_timezone', 'clicked', 'contest_login_count', 'contest_login_count_1_days', 'contest_login_count_30_days', 'contest_login_count_365_days', 'contest_login_count_7_days', 'contest_participation_count', 'contest_participation_count_1_days', 'contest_participation_count_30_days', 'contest_participation_count_365_days', 'contest_participation_count_7_days', 'forum_comments_count', 'forum_count', 'forum_expert_count', 'forum_questions_count', 'hacker_confirmation', 'ipn_count', 'ipn_count_1_days', 'ipn_count_30_days', 'ipn_count_365_days', 'ipn_count_7_days', 'ipn_read', 'ipn_read_1_days', 'ipn_read_30_days', 'ipn_read_365_days', 'ipn_read_7_days', 'opened', 'submissions_count', 'submissions_count_1_days', 'submissions_count_30_days', 'submissions_count_365_days', 'submissions_count_7_days', 'submissions_count_contest', 'submissions_cou
# ...

# %%
to_consider=['mail_category', 'mail_type','last_online', 'hacker_created_at',
            'clicked','contest_login_count','contest_participation_count',
            'forum_comments_count', 'forum_count', 'forum_expert_count',
             'forum_questions_count', 'hacker_confirmation','ipn_count',
            'ipn_read','opened','submissions_count','submissions_count_contest','submissions_count_master'
            ,'unsubscribed']

# %%
df=data.iloc[:,:][to_consider].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486048 entries, 0 to 486047
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   mail_category                485623 non-null  object
#  1   mail_type                    485623 non-null  object
#  2   last_online                  485471 non-null  float64
#  3   hacker_created_at            486048 non-null  int64
#  4   clicked                      486048 non-null  bool
#  5   contest_login_count          486048 non-null  int64
#  6   contest_participation_count  486048 non-null  int64
#  7   forum_comments_count         486048 non-null  int64
#  8   forum_count                  486048 non-null  int64
#  9   forum_expert_count           486048 non-null  int64
#  10  forum_questions_count        486048 non-null  int64
#  11  hacker_confirmation          486048 non-null  bool
# ...

# %%
df=df.iloc[:,:][df['last_online'].isna()==False].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485471 entries, 0 to 486047
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   mail_category                485046 non-null  object
#  1   mail_type                    485046 non-null  object
#  2   last_online                  485471 non-null  float64
#  3   hacker_created_at            485471 non-null  int64
#  4   clicked                      485471 non-null  bool
#  5   contest_login_count          485471 non-null  int64
#  6   contest_participation_count  485471 non-null  int64
#  7   forum_comments_count         485471 non-null  int64
#  8   forum_count                  485471 non-null  int64
#  9   forum_expert_count           485471 non-null  int64
#  10  forum_questions_count        485471 non-null  int64
#  11  hacker_confirmation          485471 non-null  bool
# ...

# %%
pd.unique(df['mail_type'])
# Out:
# array(['mail_type_1', 'mail_type_2', 'mail_type_3', 'mail_type_4', nan],
#       dtype=object)

# %%
df=df.iloc[:,:][df['mail_type'].isna()==False]

# %%
df.isna().sum()
# Out:
# mail_category                  0
# mail_type                      0
# last_online                    0
# hacker_created_at              0
# clicked                        0
# contest_login_count            0
# contest_participation_count    0
# forum_comments_count           0
# forum_count                    0
# forum_expert_count             0
# forum_questions_count          0
# hacker_confirmation            0
# ipn_count                      0
# ipn_read                       0
# opened                         0
# submissions_count              0
# submissions_count_contest      0
# submissions_count_master       0
# unsubscribed                   0
# dtype: int64

# %%
df.head(10)
# Out:
#       mail_category    mail_type   last_online  hacker_created_at  clicked  \
# 0   mail_category_2  mail_type_1  1.459520e+09         1432533023    False
# 1   mail_category_1  mail_type_1  1.461210e+09         1432184291    False
# 2   mail_category_1  mail_type_1  1.463411e+09         1433045937    False
# 3   mail_category_1  mail_type_1  1.462768e+09         1432184291    False
# 4   mail_category_4  mail_type_1  1.461248e+09         1432998058    False
# 5   mail_category_6  mail_type_1  1.457962e+09         1431945704    False
# 6   mail_category_1  mail_type_1  1.460135e+09         1432658834    False
# 7   mail_category_1  mail_type_1  1.462193e+09         1432294499    False
# 8  mail_category_13  mail_type_2  1.462860e+09         1432795707    False
# 9  mail_category_13  mail_type_2  1.462369e+09         1432059719    False
#
#    contest_login_count  contest_participation_count  forum_comments_count  \
# ...

# %%
for i in df.columns:
    if df[i].dtypes=='bool':
        print(i) #display column having boolean data type
        df[i]=df[i].astype(int) #converting boolean to integer 0-False, 1-True
# Out:
# clicked
# hacker_confirmation
# opened
# unsubscribed

# %%
df.head()
# Out:
#      mail_category    mail_type   last_online  hacker_created_at  clicked  \
# 0  mail_category_2  mail_type_1  1.459520e+09         1432533023        0
# 1  mail_category_1  mail_type_1  1.461210e+09         1432184291        0
# 2  mail_category_1  mail_type_1  1.463411e+09         1433045937        0
# 3  mail_category_1  mail_type_1  1.462768e+09         1432184291        0
# 4  mail_category_4  mail_type_1  1.461248e+09         1432998058        0
#
#    contest_login_count  contest_participation_count  forum_comments_count  \
# 0                    1                            1                     0
# 1                    3                            3                     0
# 2                    3                            3                     0
# 3                    3                            3                     0
# 4                    5                           13                     0
#
#    forum_count  forum_expert_count  forum_questions_count  \
# ...

# %%
min(df['last_online'])/(3600*24*365)
# Out:
# 43.63411558219178

# %%
pd.unique(df['mail_category'])
# Out:
# array(['mail_category_2', 'mail_category_1', 'mail_category_4',
#        'mail_category_6', 'mail_category_13', 'mail_category_3',
#        'mail_category_15', 'mail_category_7', 'mail_category_10',
#        'mail_category_9', 'mail_category_14', 'mail_category_8',
#        'mail_category_17', 'mail_category_5', 'mail_category_11',
#        'mail_category_12', 'mail_category_16', 'mail_category_18'],
#       dtype=object)

# %%
x=pd.get_dummies(df['mail_category'],prefix='cat')

# %%
x
# Out:
#         cat_mail_category_1  cat_mail_category_10  cat_mail_category_11  \
# 0                         0                     0                     0
# 1                         1                     0                     0
# 2                         1                     0                     0
# 3                         1                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 486043                    1                     0                     0
# 486044                    1                     0                     0
# 486045                    1                     0                     0
# 486046                    1                     0                     0
# 486047                    1                     0                     0
#
#         cat_mail_category_12  cat_mail_category_13  cat_mail_category_14  \
# ...
